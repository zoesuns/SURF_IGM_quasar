# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use("~/.matplotlib/presentation.mplstyle")

# %%
# plt.rcParams.keys()
# plt.rcParams["figure.figsize"]=[8,6]

# %%
plt.plot([0,1],[0,1])
plt.xlabel(r"$\rm wavelength ~ [km/s]$")
plt.ylabel(r"$\rm flux$")
# Out:
# Text(0, 0.5, '$\\rm flux$')
